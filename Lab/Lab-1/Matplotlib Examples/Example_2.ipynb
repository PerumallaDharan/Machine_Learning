# %%
#Example 02: Creating plot on dataframe
import pandas as pd
df = pd.read_csv('Pandas Numpy Examples/iris.csv')

# %%
df.hist()# Histogram
df.plot( ) # Line Graph
# Out:
# <Axes: >

# %%
df.boxplot( ) # Box plot:
# Out:
# <Axes: >
